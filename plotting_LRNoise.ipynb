# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import math

# %%
files = sorted(glob.glob("logisticRegression/results/lr_shap_noise_*.csv"))
files = sorted(files, key=lambda x: float(x.split("_")[-1].replace(".csv", "")))
n = len(files)
cols = 3
rows = math.ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(20, rows * 4))

for i, file in enumerate(files):
    ax = axes.flatten()[i]
    
    noise_level = file.split("_")[-1].replace(".csv", "")
    df = pd.read_csv(file)
    
    # Sort for consistency
    df = df.sort_values(by="mean_abs_shap", ascending=False)
    
    ax.bar(df["feature"], df["mean_abs_shap"])
    ax.set_title(f"Noise = {noise_level}")
    
    # Rotate labels (VERY important)
    ax.set_xticklabels(df["feature"], rotation=45, ha='right')
    
    ax.set_ylabel("Mean |SHAP|")

# Remove empty subplots
for j in range(i+1, len(axes.flatten())):
    fig.delaxes(axes.flatten()[j])

plt.tight_layout()
plt.show()
# Out:
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
# /var/folders/c0/qx428cwx2qx1764r7zv962vm0000gn/T/ipykernel_12490/2038004823.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df["feature"], rotation=45, ha='right')
